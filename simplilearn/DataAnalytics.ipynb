# %%
import numpy as np

arr1 = np.array([1,2,3,9])

print(arr1)
# Out:
# [1 2 3 9]

# %%
print(type(arr1))
# Out:
# <class 'numpy.ndarray'>

# %%
print(arr1.shape)
# Out:
# (4,)

# %%
arr1[3] = 7
print(arr1)
# Out:
# [1 2 3 7]

# %%
arr2 = np.array([[1,2,3],[4,5,6]])

# %%
print(arr2)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
arr2[1][0]
# Out:
# np.int64(4)

# %%
arr2[1][0] =  8
print(arr2)
# Out:
# [[1 2 3]
#  [8 5 6]]

# %%
arr2.shape
# Out:
# (2, 3)
