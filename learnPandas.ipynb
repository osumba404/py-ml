# %% [markdown]
# # Pandas Library
# Usefull for Data Processing and Analysis
#
# ## Pandas Data Frame:
# Pandas Data Frame is a two-dimensional tabular data structure with labeled axes (rows and columns)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# creating a pandas dataframe

# %%
import numpy as np

# 1. Define the URL for the original source
data_url = "http://lib.stat.cmu.edu/datasets/boston"

# 2. Read the raw data (it has a tricky format with split lines)
raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)

# 3. Stitch the split lines together using numpy
data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
target = raw_df.values[1::2, 2]

# 4. Define feature names (standard Boston column names)
feature_names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']

# 5. Create the final Pandas DataFrame
boston_df = pd.DataFrame(data, columns=feature_names)
boston_df['MEDV'] = target  # Add the target (Price) column

# View the result
print(boston_df.head())
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
# importing the boston house price data
from sklearn.datasets import fetch_california_housing
califonia_dataset = fetch_california_housing()
type(califonia_dataset)
# Out:
# sklearn.utils._bunch.Bunch

# %%
print(califonia_dataset)
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#           37.88      , -122.23      ],
#        [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#           37.86      , -122.22      ],
#        [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#           37.85      , -122.24      ],
#        ...,
#        [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#           39.43      , -121.22      ],
#        [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#           39.43      , -121.32      ],
#        [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
# ...

# %%
# pandas DataFrame
califonia_df = pd.DataFrame(califonia_dataset.data, columns = califonia_dataset.feature_names)

# %%
califonia_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
boston_df.shape
type(boston_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## importing data from a csv file to a pandas dataframe

# %%
# csv file to pandas
diabetes_df = pd.read_csv('diabetes.csv')

# %%
type(diabetes_df)
# Out:
# pandas.core.frame.DataFrame

# %%
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes_df.shape
# Out:
# (768, 9)

# %% [markdown]
# Loading the data from an exel file to a pandas DataFrame

# %%
pd.read_excel('file_path')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 pd.read_excel('file_path')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
# ...

# %% [markdown]
# ### Exporting a DataFrame to a csv file

# %%
boston_df.to_csv('boston.csv')

# %% [markdown]
# ### Exporting the pandas dataframe to an Excel file

# %%
boston_df.to_excel('boston_excel.xlsx')

# %% [markdown]
# ## Creating a dataframe with random values

# %%
random_df = pd.DataFrame(np.random.rand(20,10))

# %%
random_df.head()

# %%
random_df.shape

# %% [markdown]
# # Inspecting a DataFrame

# %%
# Findind rows and column
boston_df.shape

# %%
# first 5 rows
boston_df.head()

# %%
# last 5 rows
boston_df.tail()

# %% [markdown]
# ## Getting Information about a dataframe

# %%
boston_df.info()

# %%
# finding the no of missing values
boston_df.isnull().sum()

# %%
diabetes_df.head()

# %%
# counting the values based on the labes
diabetes_df.value_counts("Outcome")
diabetes_df.value_counts("Age")

# %% [markdown]
# ### Group values based on the mean

# %%
diabetes_df.groupby('Outcome').mean()

# %% [markdown]
# ## Statistical Measures of the data

# %%
# count or number of values
boston_df.count()

# %%
# mean value - columnwise
boston_df.mean()

# %%
# Standard deviation - columns wise
boston_df.std()

# %%
# minimum value
boston_df.min()

# %%
#maximum value
boston_df.max()

# %% [markdown]
# ### All the statisticall measures of the dataframe in one go

# %%
boston_df.describe()

# %% [markdown]
# # Manipulating a dataframe

# %%
# adding a column to a dataframe
# pandas DataFrame
# boston_df = pd.DataFrame(boston_dataset.data, columns = boston_dataset.feature_names)
boston_df.head()

# %%
# adding a column to a dataframe
# Create the 'Price' column by copying 'MEDV'
boston_df['Price'] = boston_df['MEDV']

# If you want to view it to make sure it worked
print(boston_df.head())

# %%
# locating a row using the index value
boston_df.iloc[2]
# Out:
# CRIM         0.02729
# ZN           0.00000
# INDUS        7.07000
# CHAS         0.00000
# NOX          0.46900
# RM           7.18500
# AGE         61.10000
# DIS          4.96710
# RAD          2.00000
# TAX        242.00000
# PTRATIO     17.80000
# B          392.83000
# LSTAT        4.03000
# MEDV        34.70000
# Name: 2, dtype: float64

# %%
# locating a particular column
print(boston_df.iloc[:0]) # first clumn
print(boston_df.iloc[:1]) # second column
print(boston_df.iloc[:2]) # third column
print(boston_df.iloc[:-1]) #last column
# Out:
# Empty DataFrame
# Columns: [CRIM, ZN, INDUS, CHAS, NOX, RM, AGE, DIS, RAD, TAX, PTRATIO, B, LSTAT, MEDV]
# Index: []
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE   DIS  RAD    TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.09  1.0  296.0     15.3
#
#        B  LSTAT  MEDV
# 0  396.9   4.98  24.0
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
#
#    PTRATIO      B  LSTAT  MEDV
# 0     15.3  396.9   4.98  24.0
# 1     17.8  396.9   9.14  21.6
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# ...

# %%
# locating a particular column
print(boston_df.iloc[:,0])   # first
# Out:
# 0      0.00632
# 1      0.02731
# 2      0.02729
# 3      0.03237
# 4      0.06905
#         ...
# 501    0.06263
# 502    0.04527
# 503    0.06076
# 504    0.10959
# 505    0.04741
# Name: CRIM, Length: 506, dtype: float64

# %% [markdown]
# ## Correlation
# 1. Positive Correlation
# 2. Negative Correlation

# %%
boston_df.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...
