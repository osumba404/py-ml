# %% [markdown]
# ## Constants & Variables

# %%
superhero = "Captain America"
print(superhero)
# Out:
# Captain America

# %%
superhero = "Batman"
print(superhero)
# Out:
# Batman

# %%
hero1, hero2, hero3 = "Spider Man", "The Joker",
