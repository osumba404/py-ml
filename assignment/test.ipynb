# %%
import random
for i in range(3):
    print(random.random())
x = 10
# Out:
# 0.5100034077838423
# 0.3124773078129498
# 0.00030341049661952724

# %%
import numpy as np
import pandas as pd
import matplotlib as mlp
import seaborn as sns

# %%
df = pd.read_csv('C:/Users/osumb/notebooks/assignment/flights.csv')

# %%
df.head()
# Out:
#    year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier tailnum  \
# 0  2013      1    1     517.0        2.0     830.0       11.0      UA  N14228
# 1  2013      1    1     533.0        4.0     850.0       20.0      UA  N24211
# 2  2013      1    1     542.0        2.0     923.0       33.0      AA  N619AA
# 3  2013      1    1     554.0       -6.0     812.0      -25.0      DL  N668DN
# 4  2013      1    1     554.0       -4.0     740.0       12.0      UA  N39463
#
#    flight origin dest  air_time  distance  hour  minute
# 0    1545    EWR  IAH     227.0      1400   5.0    17.0
# 1    1714    LGA  IAH     227.0      1416   5.0    33.0
# 2    1141    JFK  MIA     160.0      1089   5.0    42.0
# 3     461    LGA  ATL     116.0       762   5.0    54.0
# 4    1696    EWR  ORD     150.0       719   5.0    54.0

# %%
df['air_time'].dtype
# Out:
# dtype('float64')

# %%
df['day'].dtype
# Out:
# dtype('int64')

# %%
df['year'].dtype
# Out:
# dtype('int64')

# %%
df['origin'].dtype
# Out:
# dtype('O')

# %%
df = df.groupby(['air_time'])

# %%
df.mean(['air_time'])
# Out:
#             year      month        day     dep_time  dep_delay     arr_time  \
# air_time
# 21.0      2013.0   3.000000   2.000000  1450.000000 -10.000000  1547.000000
# 23.0      2013.0   6.500000  19.000000  2099.500000   5.000000  2227.500000
# 25.0      2013.0   4.666667  20.666667  1111.000000  -5.333333  1197.666667
# 26.0      2013.0   7.615385  11.307692  1429.769231   4.384615  1332.461538
# 27.0      2013.0   7.200000  12.800000   599.200000  -2.800000   679.400000
# ...          ...        ...        ...          ...        ...          ...
# 666.0     2013.0   4.000000  10.000000  1431.000000  61.000000  2008.000000
# 667.0     2013.0   1.000000   9.000000  1340.000000  -1.000000  2019.000000
# 671.0     2013.0   3.000000  15.000000  1342.000000   7.000000  1924.000000
# 676.0     2013.0  11.000000  12.000000   936.000000   6.000000  1630.000000
# 695.0     2013.0   3.000000  17.000000  1337.000000   2.000000  1937.000000
#
# ...
