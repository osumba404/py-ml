# %% [markdown]
# IMPORTING LIBRARIES

# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib as mpl
import seaborn as sns

# %% [markdown]
# CHECKING THE CURRENT WORKING DIRECTORY

# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/user'

# %% [markdown]
# IMPORTING A CSV FILE CALLED "salaries.csv" AND CREATING A NEW DATAFRAME CALLED "df" TO STORE THIS FILE

# %%
df=pd.read_csv("Salaries.csv")

# %% [markdown]
# CHECKING THE FIRST FIVE RECORD OF THE DATAFRAME "df"

# %%
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %% [markdown]
# CHECKING ON STATISTICAL DECRIPTIVE PROPERTIES OF THA DATASET

# %%
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %% [markdown]
# USING ".tail" FOR FETCHING THE LAST 10 RECORDS IN THE DATASET

# %%
df.tail(10)
# Out:
#          rank discipline  phd  service     sex  salary
# 68   AsstProf          A    4        2  Female   77500
# 69       Prof          A   28        7  Female  116450
# 70   AsstProf          A    8        3  Female   78500
# 71  AssocProf          B   12        9  Female   71065
# 72       Prof          B   24       15  Female  161101
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %% [markdown]
# CHECKING DATATYPES OF COLUMN SALARY USING THE ".dtype" ATTRIBUTE

# %%
df['salary'].dtype
# Out:
# dtype('int64')

# %%
df['rank'].dtype
# Out:
# dtype('O')

# %%
df.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %% [markdown]
# CHECKING DATATYPES OF MULTIPLE COLUMNS AT ONCE USING THE ".dtypes" ATTRIBUTE

# %%
df_rank=df.groupby(['rank'])

# %%
df_rank.mean()
# Out:
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %% [markdown]
# GROUPING COLUMNS BASED ON SOME SELECTED CRITERIA

# %%
df.groupby('rank')[['salary']].mean()
# Out:
#                   salary
# rank
# AssocProf   91786.230769
# AsstProf    81362.789474
# Prof       123624.804348

# %%
df.head(30)
# Out:
#          rank discipline  phd  service   sex  salary
# 0        Prof          B   56       49  Male  186960
# 1        Prof          A   12        6  Male   93000
# 2        Prof          A   23       20  Male  110515
# 3        Prof          A   40       31  Male  131205
# 4        Prof          B   20       18  Male  104800
# 5        Prof          A   20       20  Male  122400
# 6   AssocProf          A   20       17  Male   81285
# 7        Prof          A   18       18  Male  126300
# 8        Prof          A   29       19  Male   94350
# 9        Prof          A   51       51  Male   57800
# 10       Prof          B   39       33  Male  128250
# 11       Prof          B   23       23  Male  134778
# 12   AsstProf          B    1        0  Male   88000
# 13       Prof          B   35       33  Male  162200
# 14       Prof          B   25       19  Male  153750
# 15       Prof          B   17        3  Male  150480
# 16   AsstProf          B    8        3  Male   75044
# ...

# %% [markdown]
# FILTERING THE DATASET BASED ON SALARY >120000

# %%
df_sub=df[df['salary']>120000]

# %%
df_sub.head(100)
# Out:
#     rank discipline  phd  service     sex  salary
# 0   Prof          B   56       49    Male  186960
# 3   Prof          A   40       31    Male  131205
# 5   Prof          A   20       20    Male  122400
# 7   Prof          A   18       18    Male  126300
# 10  Prof          B   39       33    Male  128250
# 11  Prof          B   23       23    Male  134778
# 13  Prof          B   35       33    Male  162200
# 14  Prof          B   25       19    Male  153750
# 15  Prof          B   17        3    Male  150480
# 19  Prof          A   29       27    Male  150500
# 26  Prof          A   38       19    Male  148750
# 27  Prof          A   45       43    Male  155865
# 29  Prof          B   21       20    Male  123683
# 31  Prof          B   22       21    Male  155750
# 35  Prof          B   28       23    Male  126933
# 36  Prof          B   45       45    Male  146856
# 39  Prof          B   18       18  Female  129000
# 40  Prof          A   39       36  Female  137000
# ...

# %% [markdown]
# FILTERING THE DATASET BASED ON GENDER "female"

# %%
df_f=df[df['sex']=='Female']

# %%
df_f.head(50)
# Out:
#          rank discipline  phd  service     sex  salary
# 39       Prof          B   18       18  Female  129000
# 40       Prof          A   39       36  Female  137000
# 41  AssocProf          A   13        8  Female   74830
# 42   AsstProf          B    4        2  Female   80225
# 43   AsstProf          B    5        0  Female   77000
# 44       Prof          B   23       19  Female  151768
# 45       Prof          B   25       25  Female  140096
# 46   AsstProf          B   11        3  Female   74692
# 47  AssocProf          B   11       11  Female  103613
# 48       Prof          B   17       17  Female  111512
# 49       Prof          B   17       18  Female  122960
# 50   AsstProf          B   10        5  Female   97032
# 51       Prof          B   20       14  Female  127512
# 52       Prof          A   12        0  Female  105000
# 53   AsstProf          A    5        3  Female   73500
# 54  AssocProf          A   25       22  Female   62884
# ...

# %%
df['salary']
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
# 5     122400
# 6      81285
# 7     126300
# 8      94350
# 9      57800
# 10    128250
# 11    134778
# 12     88000
# 13    162200
# 14    153750
# 15    150480
# 16     75044
# 17     92000
# 18    107300
# 19    150500
# 20     92000
# 21    103106
# 22     73000
# 23     85000
# 24     91100
# 25     99418
# 26    148750
# 27    155865
# 28     91300
# 29    123683
#        ...
# 48    111512
# 49    122960
# 50     97032
# 51    127512
# 52    105000
# 53     73500
# 54     62884
# 55     72500
# 56     77500
# 57     72500
# 58    144651
# 59    103994
# 60     92000
# 61    103750
# 62    109650
# 63     91000
# 64     73300
# 65    117555
# 66     63100
# 67     90450
# 68     77500
# 69    116450
# 70     78500
# 71     71065
# 72    161101
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %% [markdown]
# FILTERING BASED ON SELECTED COLUMNS "rank and Salary"

# %%
df[['rank','salary']]
# Out:
#          rank  salary
# 0        Prof  186960
# 1        Prof   93000
# 2        Prof  110515
# 3        Prof  131205
# 4        Prof  104800
# 5        Prof  122400
# 6   AssocProf   81285
# 7        Prof  126300
# 8        Prof   94350
# 9        Prof   57800
# 10       Prof  128250
# 11       Prof  134778
# 12   AsstProf   88000
# 13       Prof  162200
# 14       Prof  153750
# 15       Prof  150480
# 16   AsstProf   75044
# 17   AsstProf   92000
# 18       Prof  107300
# 19       Prof  150500
# 20   AsstProf   92000
# 21       Prof  103106
# 22   AsstProf   73000
# 23   AsstProf   85000
# 24       Prof   91100
# 25       Prof   99418
# 26       Prof  148750
# 27       Prof  155865
# 28   AsstProf   91300
# 29       Prof  123683
# ..        ...     ...
# 48       Prof  111512
# 49       Prof  122960
# 50   AsstProf   97032
# 51       Prof  127512
# 52       Prof  105000
# 53   AsstProf   73500
# 54  AssocProf   62884
# 55   AsstProf   72500
# 56  AssocProf   77500
# ...

# %% [markdown]
# SLICING THE DATASET USING "loc" TO GET THE ROWS BETWEEEN 10 AND 20

# %%
df[10:20]
# Out:
#         rank discipline  phd  service   sex  salary
# 10      Prof          B   39       33  Male  128250
# 11      Prof          B   23       23  Male  134778
# 12  AsstProf          B    1        0  Male   88000
# 13      Prof          B   35       33  Male  162200
# 14      Prof          B   25       19  Male  153750
# 15      Prof          B   17        3  Male  150480
# 16  AsstProf          B    8        3  Male   75044
# 17  AsstProf          B    4        0  Male   92000
# 18      Prof          A   19        7  Male  107300
# 19      Prof          A   29       27  Male  150500

# %% [markdown]
# SLICING THE DATASET USING "loc" AND SELECTING SPECIFIC COLUMNS

# %%
df_sub.loc[10:20,['rank','sex','salary']]
# Out:
#     rank   sex  salary
# 10  Prof  Male  128250
# 11  Prof  Male  134778
# 13  Prof  Male  162200
# 14  Prof  Male  153750
# 15  Prof  Male  150480
# 19  Prof  Male  150500

# %%
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %% [markdown]
# SLICING THE DATASET USING "iloc" WHICH USES COLUMN INDEXES INSTEAD OF COLUM NAMES

# %%
df_sub.iloc[10:20,[0,3,5]]
# Out:
#     rank  service  salary
# 26  Prof       19  148750
# 27  Prof       43  155865
# 29  Prof       20  123683
# 31  Prof       21  155750
# 35  Prof       23  126933
# 36  Prof       45  146856
# 39  Prof       18  129000
# 40  Prof       36  137000
# 44  Prof       19  151768
# 45  Prof       25  140096

# %% [markdown]
# SLICING THE DATASET USING "iloc"TO GET FIRST ROW

# %%
df.iloc[0]
# Out:
# rank            Prof
# discipline         B
# phd               56
# service           49
# sex             Male
# salary        186960
# Name: 0, dtype: object

# %% [markdown]
# SLICING THE DATASET USING "iloc"TO GET 32nd ROW

# %%
df.iloc[32]
# Out:
# rank            Prof
# discipline         A
# phd               27
# service           19
# sex             Male
# salary        103275
# Name: 32, dtype: object

# %% [markdown]
# SLICING THE DATASET USING "iloc"TO GET LAST ROW

# %%
df.iloc[-1]
# Out:
# rank            Prof
# discipline         A
# phd               23
# service           15
# sex           Female
# salary        109646
# Name: 77, dtype: object

# %% [markdown]
# SLICING THE DATASET USING "iloc"TO GET LAST COLUMN

# %%
df.iloc[:,-1]
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
# 5     122400
# 6      81285
# 7     126300
# 8      94350
# 9      57800
# 10    128250
# 11    134778
# 12     88000
# 13    162200
# 14    153750
# 15    150480
# 16     75044
# 17     92000
# 18    107300
# 19    150500
# 20     92000
# 21    103106
# 22     73000
# 23     85000
# 24     91100
# 25     99418
# 26    148750
# 27    155865
# 28     91300
# 29    123683
#        ...
# 48    111512
# 49    122960
# 50     97032
# 51    127512
# 52    105000
# 53     73500
# 54     62884
# 55     72500
# 56     77500
# 57     72500
# 58    144651
# 59    103994
# 60     92000
# 61    103750
# 62    109650
# 63     91000
# 64     73300
# 65    117555
# 66     63100
# 67     90450
# 68     77500
# 69    116450
# 70     78500
# 71     71065
# 72    161101
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %%
df.head(10)
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 1       Prof          A   12        6  Male   93000
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285
# 7       Prof          A   18       18  Male  126300
# 8       Prof          A   29       19  Male   94350
# 9       Prof          A   51       51  Male   57800

# %%
df_sorted=df.sort_values(by='service')

# %%
df_sorted.head(10)
# Out:
#         rank discipline  phd  service     sex  salary
# 55  AsstProf          A    2        0  Female   72500
# 23  AsstProf          A    2        0    Male   85000
# 43  AsstProf          B    5        0  Female   77000
# 17  AsstProf          B    4        0    Male   92000
# 12  AsstProf          B    1        0    Male   88000
# 52      Prof          A   12        0  Female  105000
# 57  AsstProf          A    3        1  Female   72500
# 28  AsstProf          B    7        2    Male   91300
# 42  AsstProf          B    4        2  Female   80225
# 22  AsstProf          A    4        2    Male   73000

# %%
df_sorted=df.sort_values(by=['service','salary'],ascending=[True,False])

# %%
df_sorted.head(20)
# Out:
#         rank discipline  phd  service     sex  salary
# 52      Prof          A   12        0  Female  105000
# 17  AsstProf          B    4        0    Male   92000
# 12  AsstProf          B    1        0    Male   88000
# 23  AsstProf          A    2        0    Male   85000
# 43  AsstProf          B    5        0  Female   77000
# 55  AsstProf          A    2        0  Female   72500
# 57  AsstProf          A    3        1  Female   72500
# 28  AsstProf          B    7        2    Male   91300
# 42  AsstProf          B    4        2  Female   80225
# 68  AsstProf          A    4        2  Female   77500
# 22  AsstProf          A    4        2    Male   73000
# 15      Prof          B   17        3    Male  150480
# 60  AsstProf          B    3        3  Female   92000
# 38  AsstProf          B    4        3    Male   91000
# 70  AsstProf          A    8        3  Female   78500
# 16  AsstProf          B    8        3    Male   75044
# ...

# %% [markdown]
# IMPORTING A CSV FILE CALLED "flights.csv" AND CREATING A NEW DATAFRAME CALLED "df2" TO STORE THIS FILE

# %%
df2=pd.read_csv("flights.csv")

# %%
df2.head()
# Out:
#    year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier tailnum  \
# 0  2013      1    1     517.0        2.0     830.0       11.0      UA  N14228
# 1  2013      1    1     533.0        4.0     850.0       20.0      UA  N24211
# 2  2013      1    1     542.0        2.0     923.0       33.0      AA  N619AA
# 3  2013      1    1     554.0       -6.0     812.0      -25.0      DL  N668DN
# 4  2013      1    1     554.0       -4.0     740.0       12.0      UA  N39463
#
#    flight origin dest  air_time  distance  hour  minute
# 0    1545    EWR  IAH     227.0      1400   5.0    17.0
# 1    1714    LGA  IAH     227.0      1416   5.0    33.0
# 2    1141    JFK  MIA     160.0      1089   5.0    42.0
# 3     461    LGA  ATL     116.0       762   5.0    54.0
# 4    1696    EWR  ORD     150.0       719   5.0    54.0

# %%
df2.tail()
# Out:
#         year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 160749  2013      9   30    2105.0       -1.0    2329.0      -25.0      UA
# 160750  2013      9   30    2121.0       21.0    2349.0      -25.0      DL
# 160751  2013      9   30    2140.0        0.0      10.0      -30.0      AA
# 160752  2013      9   30    2149.0       -7.0    2245.0      -23.0      UA
# 160753  2013      9   30    2233.0       80.0     112.0       42.0      UA
#
#        tailnum  flight origin dest  air_time  distance  hour  minute
# 160749  N477UA     475    EWR  IAH     175.0      1400  21.0     5.0
# 160750  N193DN    2363    JFK  LAX     296.0      2475  21.0    21.0
# 160751  N335AA     185    JFK  LAX     298.0      2475  21.0    40.0
# 160752  N813UA     523    EWR  BOS      37.0       200  21.0    49.0
# 160753  N578UA     471    EWR  SFO     318.0      2565  22.0    33.0

# %%
df2.describe()
# Out:
#            year          month            day       dep_time      dep_delay  \
# count  160754.0  160754.000000  160754.000000  158418.000000  158418.000000
# mean     2013.0       6.547395      15.716567    1316.146006       9.463773
# std         0.0       3.410001       8.762794     470.823715      36.545109
# min      2013.0       1.000000       1.000000       1.000000     -33.000000
# 25%      2013.0       4.000000       8.000000     855.000000      -5.000000
# 50%      2013.0       7.000000      16.000000    1345.000000      -2.000000
# 75%      2013.0      10.000000      23.000000    1725.000000       7.000000
# max      2013.0      12.000000      31.000000    2400.000000    1014.000000
#
#             arr_time      arr_delay         flight       air_time  \
# count  158275.000000  157927.000000  160754.000000  157927.000000
# mean     1517.471161       2.094537    1156.344987     180.685158
# std       510.695413      41.479349     695.884283      97.507866
# ...

# %% [markdown]
# CHECKING FOR EMPTY COLUMN /MISSSING COLUMN VALUES USING THE "isnull" FUNCTION

# %%
df2[df2.isnull().any(axis=1)].head(100)
# Out:
#       year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 330   2013      1    1    1807.0       29.0    2251.0        NaN      UA
# 403   2013      1    1       NaN        NaN       NaN        NaN      AA
# 404   2013      1    1       NaN        NaN       NaN        NaN      AA
# 855   2013      1    2    2145.0       16.0       NaN        NaN      UA
# 858   2013      1    2       NaN        NaN       NaN        NaN      AA
# 859   2013      1    2       NaN        NaN       NaN        NaN      AA
# 860   2013      1    2       NaN        NaN       NaN        NaN      UA
# 1067  2013      1    3    1348.0       -2.0    1821.0        NaN      DL
# 1275  2013      1    3       NaN        NaN       NaN        NaN      AA
# 1276  2013      1    3       NaN        NaN       NaN        NaN      AA
# 1277  2013      1    3       NaN        NaN       NaN        NaN      AA
# 1278  2013      1    3       NaN        NaN       NaN        NaN      AA
# ...

# %% [markdown]
# COMPUTING DESCRIPTIVE STATISTICAL MEASURES "min, mean and max"

# %%
df2[['dep_delay','arr_delay']].agg(['min','mean','max'])
# Out:
#         dep_delay    arr_delay
# min    -33.000000   -75.000000
# mean     9.463773     2.094537
# max   1014.000000  1007.000000

# %%
df2.describe()
# Out:
#            year          month            day       dep_time      dep_delay  \
# count  160754.0  160754.000000  160754.000000  158418.000000  158418.000000
# mean     2013.0       6.547395      15.716567    1316.146006       9.463773
# std         0.0       3.410001       8.762794     470.823715      36.545109
# min      2013.0       1.000000       1.000000       1.000000     -33.000000
# 25%      2013.0       4.000000       8.000000     855.000000      -5.000000
# 50%      2013.0       7.000000      16.000000    1345.000000      -2.000000
# 75%      2013.0      10.000000      23.000000    1725.000000       7.000000
# max      2013.0      12.000000      31.000000    2400.000000    1014.000000
#
#             arr_time      arr_delay         flight       air_time  \
# count  158275.000000  157927.000000  160754.000000  157927.000000
# mean     1517.471161       2.094537    1156.344987     180.685158
# std       510.695413      41.479349     695.884283      97.507866
# ...

# %% [markdown]
# IMPORTING CHARTING LIBRARY

# %%
# %matplotlib inline

# %%
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %% [markdown]
# CREATING A BAR GRAPH FROM OUR SALARIES DATAFRAME USING THE COMUMN "salary"

# %%
graph1=df['salary'].plot(kind='bar')

# %% [raw]
# CREATING A FILTER FOR THOSE EARNING ABOVE 155000 FROM THE DATAFRAME "df" AND SAVING IT AS "df_sub1"

# %%
df_sub1=df[df['salary']>155000]

# %%
df_sub1.head(10)
# Out:
#     rank discipline  phd  service     sex  salary
# 0   Prof          B   56       49    Male  186960
# 13  Prof          B   35       33    Male  162200
# 27  Prof          A   45       43    Male  155865
# 31  Prof          B   22       21    Male  155750
# 72  Prof          B   24       15  Female  161101

# %% [markdown]
# PLOTTING A GRAPH AND DESCRIBING ITS PARAMETERS "TYPE,XLABEL AND YLABEL"

# %%
graph2=df_sub1.plot(kind='bar')
graph2.set_xlabel("emp. serial number")
graph2.set_ylabel("salary")
# Out:
# Text(0,0.5,'salary')
